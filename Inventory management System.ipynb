# %% [markdown]
# # Inventory Mangement System

# %% [markdown]
# Importing libraries

# %%
import json
from datetime import date

# %%
def new_prod():
    '''
    Makes a dictionary for the new product

    Returns
    -------
    None.

    '''
    print("========================================================")
    print("Enter Details of new product:")
    new_product={}
    id=int(input("Enter product Id for new entry:"))
    new_product[id]={}
    new_product[id]["Name"]=input("Enter the name of product:")
    new_product[id]["Company"]=input("Product is manufactured by:")
    new_product[id]["Exp_date"]=input("Enter product Expiry date:")
    new_product[id]["Price"]=float(input("Enter price of Product:"))
    new_product[id]["Quantity"]=int(input("Enter The qunatity of product:"))
        
    try: 
        with open("records.json","r+") as record:
            data=json.load(record)
            data.update(new_product)
            record.seek(0)
            json.dump(data,record)
    except:
        with open("records.json","w") as record:
            json.dump(new_product,record)
    Invetory()

# %%
def new_bill():
    '''
    Bill making function

    Returns
    -------
    None.

    '''
    print("=============================================================")
    print("Creating New bill Enter all details:")
    new_cust={}
    bill=0.00
    id=int(input("Enter Id for new customer:"))
    new_cust[id]={}
    new_cust[id]["Name"]=input("Enter Name of customer:")
    new_cust[id]["Mobile"]=input("Enter customer mobile Number:")
    new_cust[id]["Bill_Date"]=str(date.today())
    print("Now you can start shoping")
    
    while(1):
       record=open("records.json","r+")
       data=json.load(record)
       print("id \t Name \t\t Company \t\t Price \t\t Qunatity")
       for prod_id,value in data.items():
           print(prod_id+" \t "+value["Name"]+" \t\t "+value["Company"]+" \t\t "+str(value["Price"])+" \t\t "+str(value["Quantity"]))
       record.close()
       
       product=(input("Enter product Id for item needed:"))
       if product not in data.keys():
           print("wrong Entry try again")
           continue
       
       quant=int(input("Enter Quantity needed:"))
       bill=bill+(data[product]["Price"]*quant)
       
       record2=open("records.json","r+") 
       data=json.load(record2)
       data[product]["Quantity"]=data[product]["Quantity"]-quant
       record2.seek(0)
       json.dump(data,record2)
       record2.truncate()
       record2.close()
       
       
       c=input("Do you want to continue purchase(Y/N):")
       if c=="N" or c == "n":
           print("Your bill Amount is "+str(bill))
           break
       
       
       
    new_cust[id]["bill"]=bill
    
    try: 
        with open("billing.json","r+") as bills:
            data=json.load(bills)
            data.update(new_cust)
            bills.seek(0)
            json.dump(data,bills)
    
    except:
        with open("billing.json","w") as bills:
            json.dump(new_cust,bills)
    billing()

# %%
def Invetory():
    '''
    This is the function which gives options what you can do with inventory bsic functions
    like: insert, update, delete

    Returns nothing just gives us the view for inventory
    -------

    '''
    print("\t\t ___________________________________________")
    print("\t\t|            Update the Inventory           |")
    print("\t\t|___________________________________________|")
    print("\t\t Select Action to perform: \n\t\t 1. Enter New product \n\t\t 2. BACK")
    n=int(input("\t\tEnter your choice of action:"))
    if n==1:
        new_prod()
    elif n==2:
        print("\t\t Exiting...")
        print("\n\n\n")
        first_view()
    else:
        print("\t\t wrong choice restarting...")
        print("\n\n\n")
        Invetory()

# %%
def billing():
    '''
    This function just save all the billing things
    save all the billing things in billing files

    Returns nothing just gives view for the billing things
    -------

    '''
    print("\t\t ___________________________________________")
    print("\t\t|               Billing format              |")
    print("\t\t|___________________________________________|")
    print("\t\t Select Action to perform: \n\t\t 1. Make NEW Bill \n\t\t 2. BACK")
    n=int(input("\t\tEnter your choice of action:"))
    if n==1:
        new_bill()
    elif n==2:
        print("\t\t Exiting...")
        print("\n\n\n")
        first_view()
    else:
        print("\t\t wrong choice restarting...")
        print("\n\n\n")
        billing()

# %%
def first_view():
    '''
    This is the First thing you see when you run the program it gives choice of actions to that can
    be done by the system

    Returns nothing just gives proper work flow 
    -------

    '''
    print("\t\t ___________________________________________")
    print("\t\t|        Inventory Mangement System         |")
    print("\t\t|___________________________________________|")
    print("\t\t Select Action to perform: \n\t\t 1. Update the Inventory \n\t\t 2. Make the bill\n\t\t 3.Exit")
    n=int(input("\t\tEnter your choice of action:"))
    if n==1:
        Invetory()
    elif n==2:
        billing()
    elif n==3:
        return None
    else:
        print("\t\t wrong choice restarting...")
        print("\n\n\n")
        first_view()

# %%
first_view()
# Out:
# 		 ___________________________________________
# 		|        Inventory Mangement System         |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Update the Inventory
# 		 2. Make the bill
# 		 3.Exit
# 		Enter your choice of action:1
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:01
# Enter the name of product:R pen
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:5
# Enter The qunatity of product:4000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:02
# Enter the name of product:Qpen
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:10
# Enter The qunatity of product:5000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:03
# Enter the name of product:Wpen
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:20
# Enter The qunatity of product:2000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:04
# Enter the name of product:B pen
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:15
# Enter The qunatity of product:3000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:05
# Enter the name of product:Bread
# Product is manufactured by:Harvest
# Enter product Expiry date:3-9-2021
# Enter price of Product:35
# Enter The qunatity of product:20
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:06
# Enter the name of product:coal
# Product is manufactured by:ground
# Enter product Expiry date:15-9-2025
# Enter price of Product:40
# Enter The qunatity of product:5000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:07
# Enter the name of product:milk
# Product is manufactured by:amul
# Enter product Expiry date:3-9-2021
# Enter price of Product:42
# Enter The qunatity of product:30
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:08
# Enter the name of product:butter
# Product is manufactured by:amul
# Enter product Expiry date:3-11-2021
# Enter price of Product:56
# Enter The qunatity of product:40
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:09
# Enter the name of product:butter
# Product is manufactured by:cad
# Enter product Expiry date:3-12-2021
# Enter price of Product:55
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:10
# Enter the name of product:choco
# Product is manufactured by:cornflakes
# Enter product Expiry date:7-2022
# Enter price of Product:89
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:11
# Enter the name of product:kitkat
# Product is manufactured by:cadbury
# Enter product Expiry date:11-2021
# Enter price of Product:30
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:12
# Enter the name of product:milk
# Product is manufactured by:motherdairy
# Enter product Expiry date:3-09-2021
# Enter price of Product:44
# Enter The qunatity of product:20
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:13
# Enter the name of product:cutter
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:10
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:14
# Enter the name of product:register
# Product is manufactured by:doms
# Enter product Expiry date:NA
# Enter price of Product:45
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:15
# Enter the name of product:Register
# Product is manufactured by:nat
# Enter product Expiry date:NA
# Enter price of Product:55
# Enter The qunatity of product:62
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:16
# Enter the name of product:Register
# Product is manufactured by:class
# Enter product Expiry date:NA
# Enter price of Product:60
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:17
# Enter the name of product:Register
# Product is manufactured by:classmate
# Enter product Expiry date:70
# Enter price of Product:90
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:18
# Enter the name of product:water bottle
# Product is manufactured by:milton
# Enter product Expiry date:NA
# Enter price of Product:400
# Enter The qunatity of product:10
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:19
# Enter the name of product:Bottle
# Product is manufactured by:coco
# Enter product Expiry date:NA
# Enter price of Product:500
# Enter The qunatity of product:20
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:20
# Enter the name of product:cola
# Product is manufactured by:cocacola
# Enter product Expiry date:30-08-2021
# Enter price of Product:40
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:21
# 		 wrong choice restarting...
#
#
#
#
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:21
# Enter the name of product:miranda
# Product is manufactured by:kola
# Enter product Expiry date:12-2021
# Enter price of Product:50
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:22
# Enter the name of product:icecreame
# Product is manufactured by:amul
# Enter product Expiry date:23-09-2021
# Enter price of Product:40
# Enter The qunatity of product:30
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:23
# Enter the name of product:ice
# Product is manufactured by:water
# Enter product Expiry date:2-09-2021
# Enter price of Product:2
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:24
# Enter the name of product:goli
# Product is manufactured by:hajmola
# Enter product Expiry date:10-2021
# Enter price of Product:5
# Enter The qunatity of product:80
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:25
# Enter the name of product:anardana
# Product is manufactured by:MDH
# Enter product Expiry date:11-2021
# Enter price of Product:80
# Enter The qunatity of product:20
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:26
# Enter the name of product:haldi
# Product is manufactured by:MDH
# Enter product Expiry date:12-2021
# Enter price of Product:75
# Enter The qunatity of product:500
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:27
# Enter the name of product:Mirch
# Product is manufactured by:MDH
# Enter product Expiry date:12-2021
# Enter price of Product:80
# Enter The qunatity of product:50
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:28
# Enter the name of product:Sauf
# Product is manufactured by:karnat
# Enter product Expiry date:12-2021
# Enter price of Product:40
# Enter The qunatity of product:60
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:29
# Enter the name of product:pencil
# Product is manufactured by:Nataja
# Enter product Expiry date:NA
# Enter price of Product:5
# Enter The qunatity of product:5000
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:1
# ========================================================
# Enter Details of new product:
# Enter product Id for new entry:30
# Enter the name of product:rubber
# Product is manufactured by:TY
# Enter product Expiry date:NA
# Enter price of Product:6
# Enter The qunatity of product:40
# 		 ___________________________________________
# 		|            Update the Inventory           |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Enter New product
# 		 2. BACK
# 		Enter your choice of action:2
# 		 Exiting...
#
#
#
#
# 		 ___________________________________________
# 		|        Inventory Mangement System         |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Update the Inventory
# 		 2. Make the bill
# 		 3.Exit
# 		Enter your choice of action:2
# 		 ___________________________________________
# 		|               Billing format              |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Make NEW Bill
# 		 2. BACK
# 		Enter your choice of action:1
# =============================================================
# Creating New bill Enter all details:
# Enter Id for new customer:101
# Enter Name of customer:Ankit
# Enter customer mobile Number:9810632578
# Now you can start shoping
# id 	 Name 		 Company 		 Price 		 Qunatity
# 1 	 R pen 		 nat 		 5.0 		 4000
# 2 	 Qpen 		 nat 		 10.0 		 5000
# 3 	 Wpen 		 nat 		 20.0 		 2000
# 4 	 B pen 		 nat 		 15.0 		 3000
# 5 	 Bread 		 Harvest 		 35.0 		 20
# 6 	 coal 		 ground 		 40.0 		 5000
# 7 	 milk 		 amul 		 42.0 		 30
# 8 	 butter 		 amul 		 56.0 		 40
# 9 	 butter 		 cad 		 55.0 		 50
# 10 	 choco 		 cornflakes 		 89.0 		 60
# 11 	 kitkat 		 cadbury 		 30.0 		 60
# 12 	 milk 		 motherdairy 		 44.0 		 20
# 13 	 cutter 		 nat 		 10.0 		 60
# 14 	 register 		 doms 		 45.0 		 50
# 15 	 Register 		 nat 		 55.0 		 62
# 16 	 Register 		 class 		 60.0 		 50
# 17 	 Register 		 classmate 		 90.0 		 60
# 18 	 water bottle 		 milton 		 400.0 		 10
# 19 	 Bottle 		 coco 		 500.0 		 20
# 20 	 cola 		 cocacola 		 40.0 		 50
# 21 	 miranda 		 kola 		 50.0 		 50
# 22 	 icecreame 		 amul 		 40.0 		 30
# 23 	 ice 		 water 		 2.0 		 60
# 24 	 goli 		 hajmola 		 5.0 		 80
# 25 	 anardana 		 MDH 		 80.0 		 20
# 26 	 haldi 		 MDH 		 75.0 		 500
# 27 	 Mirch 		 MDH 		 80.0 		 50
# 28 	 Sauf 		 karnat 		 40.0 		 60
# 29 	 pencil 		 Nataja 		 5.0 		 5000
# 30 	 rubber 		 TY 		 6.0 		 40
# Enter product Id for item needed:30
# Enter Quantity needed:20
# Do you want to continue purchase(Y/N):y
# id 	 Name 		 Company 		 Price 		 Qunatity
# 1 	 R pen 		 nat 		 5.0 		 4000
# 2 	 Qpen 		 nat 		 10.0 		 5000
# 3 	 Wpen 		 nat 		 20.0 		 2000
# 4 	 B pen 		 nat 		 15.0 		 3000
# 5 	 Bread 		 Harvest 		 35.0 		 20
# 6 	 coal 		 ground 		 40.0 		 5000
# 7 	 milk 		 amul 		 42.0 		 30
# 8 	 butter 		 amul 		 56.0 		 40
# 9 	 butter 		 cad 		 55.0 		 50
# 10 	 choco 		 cornflakes 		 89.0 		 60
# 11 	 kitkat 		 cadbury 		 30.0 		 60
# 12 	 milk 		 motherdairy 		 44.0 		 20
# 13 	 cutter 		 nat 		 10.0 		 60
# 14 	 register 		 doms 		 45.0 		 50
# 15 	 Register 		 nat 		 55.0 		 62
# 16 	 Register 		 class 		 60.0 		 50
# 17 	 Register 		 classmate 		 90.0 		 60
# 18 	 water bottle 		 milton 		 400.0 		 10
# 19 	 Bottle 		 coco 		 500.0 		 20
# 20 	 cola 		 cocacola 		 40.0 		 50
# 21 	 miranda 		 kola 		 50.0 		 50
# 22 	 icecreame 		 amul 		 40.0 		 30
# 23 	 ice 		 water 		 2.0 		 60
# 24 	 goli 		 hajmola 		 5.0 		 80
# 25 	 anardana 		 MDH 		 80.0 		 20
# 26 	 haldi 		 MDH 		 75.0 		 500
# 27 	 Mirch 		 MDH 		 80.0 		 50
# 28 	 Sauf 		 karnat 		 40.0 		 60
# 29 	 pencil 		 Nataja 		 5.0 		 5000
# 30 	 rubber 		 TY 		 6.0 		 20
# Enter product Id for item needed:25
# Enter Quantity needed:10
# Do you want to continue purchase(Y/N):y
# id 	 Name 		 Company 		 Price 		 Qunatity
# 1 	 R pen 		 nat 		 5.0 		 4000
# 2 	 Qpen 		 nat 		 10.0 		 5000
# 3 	 Wpen 		 nat 		 20.0 		 2000
# 4 	 B pen 		 nat 		 15.0 		 3000
# 5 	 Bread 		 Harvest 		 35.0 		 20
# 6 	 coal 		 ground 		 40.0 		 5000
# 7 	 milk 		 amul 		 42.0 		 30
# 8 	 butter 		 amul 		 56.0 		 40
# 9 	 butter 		 cad 		 55.0 		 50
# 10 	 choco 		 cornflakes 		 89.0 		 60
# 11 	 kitkat 		 cadbury 		 30.0 		 60
# 12 	 milk 		 motherdairy 		 44.0 		 20
# 13 	 cutter 		 nat 		 10.0 		 60
# 14 	 register 		 doms 		 45.0 		 50
# 15 	 Register 		 nat 		 55.0 		 62
# 16 	 Register 		 class 		 60.0 		 50
# 17 	 Register 		 classmate 		 90.0 		 60
# 18 	 water bottle 		 milton 		 400.0 		 10
# 19 	 Bottle 		 coco 		 500.0 		 20
# 20 	 cola 		 cocacola 		 40.0 		 50
# 21 	 miranda 		 kola 		 50.0 		 50
# 22 	 icecreame 		 amul 		 40.0 		 30
# 23 	 ice 		 water 		 2.0 		 60
# 24 	 goli 		 hajmola 		 5.0 		 80
# 25 	 anardana 		 MDH 		 80.0 		 10
# 26 	 haldi 		 MDH 		 75.0 		 500
# 27 	 Mirch 		 MDH 		 80.0 		 50
# 28 	 Sauf 		 karnat 		 40.0 		 60
# 29 	 pencil 		 Nataja 		 5.0 		 5000
# 30 	 rubber 		 TY 		 6.0 		 20
# Enter product Id for item needed:10
# Enter Quantity needed:20
# Do you want to continue purchase(Y/N):n
# Your bill Amount is 2700.0
# 		 ___________________________________________
# 		|               Billing format              |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Make NEW Bill
# 		 2. BACK
# 		Enter your choice of action:2
# 		 Exiting...
#
#
#
#
# 		 ___________________________________________
# 		|        Inventory Mangement System         |
# 		|___________________________________________|
# 		 Select Action to perform:
# 		 1. Update the Inventory
# 		 2. Make the bill
# 		 3.Exit
# 		Enter your choice of action:3
